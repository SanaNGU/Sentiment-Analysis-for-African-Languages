# %%
import pandas as pd
import os
from matplotlib import pyplot as plt
DataPath= '/home/sanala/Juputer try/afrisenti/TaskA/train'   #change it to your path
#data
for i in ['am', 'dz' ,'ha', 'ig', 'kr' ,'ma' ,'pcm' ,'pt' ,'sw' ,'ts' ,'twi' ,'yo'] :
    train_data = pd.read_csv(os.path.join(DataPath,i+'_train.tsv'), sep='\t')
    print(f"Data statistcs for {i}_train.tsv are \n{train_data['label'].value_counts()}")
    sns.countplot(train_data.label)
    plt.xlabel('label for {i}_train')
    plt.show()
# Out:
# Data statistcs for am_train.tsv are
# neutral     3104
# negative    1548
# positive    1332
# Name: label, dtype: int64
# /home/sanala/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Data statistcs for dz_train.tsv are
# negative    892
# positive    417
# neutral     342
# Name: label, dtype: int64
# /home/sanala/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Data statistcs for ha_train.tsv are
# neutral     4912
# positive    4687
# negative    4573
# Name: label, dtype: int64
# /home/sanala/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Data statistcs for ig_train.tsv are
# neutral     4508
# positive    3084
# negative    2600
# Name: label, dtype: int64
# /home/sanala/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Data statistcs for kr_train.tsv are
# neutral     1257
# negative    1146
# positive     899
# Name: label, dtype: int64
# /home/sanala/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Data statistcs for ma_train.tsv are
# neutral     2161
# positive    1758
# negative    1664
# Name: label, dtype: int64
# /home/sanala/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Data statistcs for pcm_train.tsv are
# negative    3241
# positive    1808
# neutral       72
# Name: label, dtype: int64
# /home/sanala/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Data statistcs for pt_train.tsv are
# neutral     1600
# negative     782
# positive     681
# Name: label, dtype: int64
# /home/sanala/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Data statistcs for sw_train.tsv are
# neutral     1072
# positive     547
# negative     191
# Name: label, dtype: int64
# /home/sanala/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Data statistcs for ts_train.tsv are
# positive    384
# negative    284
# neutral     136
# Name: label, dtype: int64
# /home/sanala/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Data statistcs for twi_train.tsv are
# positive    1644
# negative    1315
# neutral      522
# Name: label, dtype: int64
# /home/sanala/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Data statistcs for yo_train.tsv are
# positive    3542
# neutral     3108
# negative    1872
# Name: label, dtype: int64
# /home/sanala/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
